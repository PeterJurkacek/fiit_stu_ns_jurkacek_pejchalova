# %% [markdown]
# # Čo treba
# Neural network implementation: An implementation of your baseline neural model that is able to train. You should also provide a documentation of the architecture of this model.
#
# We expect you to consult the expected scope of data analysis as well as the neural architecture with your teacher. Both documents and the code should be versioned on your GitHub and submitted to AIS before the deadline.

# %% [markdown]
# # Implementácia neurónovej siete
# - Opis architektúry modelu
